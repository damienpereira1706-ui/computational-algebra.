# %% [markdown]
# make it equal to 50

# %%
#place your parenthesis here
x = (4+ (5/(2 +3)) + 2)^2 +1
# Out:
# 50.0

# %%
import Pkg
Pkg.add("Plots")
# Out:
#     Updating registry at `C:\Users\DAMIEN\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed GR_jll ─────────────────────── v0.73.26+0
#    Installed Opus_jll ───────────────────── v1.6.1+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed JpegTurbo_jll ──────────────── v3.1.5+0
#    Installed LoggingExtras ──────────────── v1.2.0
#    Installed Libmount_jll ───────────────── v2.42.0+0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed GR ─────────────────────────── v0.73.26
#    Installed LERC_jll ───────────────────── v4.1.0+0
#    Installed ConcurrentUtilities ────────── v2.5.1
#    Installed Contour ────────────────────── v0.6.3
#    Installed Measures ───────────────────── v0.3.3
#    Installed Grisu ──────────────────────── v1.0.2
# ...

# %%
f(x) = 5x
f(3)
using Plots 
gr()
plot(f, -19, 10)
plot!(aspect_ratio = 2, xlabel = "x", ylabel = "y")
g(x) = 0
plot!(g, -15,15)

# %%
#now declare both of those equations as code functions y1(x) and y2(x)
using Plots 
gr()
# your code here
y1(x) = (x+2) /5
y2(x) = 4-x


#Plot them on the same graph.  This shows another way to plot multiple things at once
plot([y1,y2], -5, 5)
